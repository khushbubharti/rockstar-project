# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/TechnologyIndex.csv')

# %%
import matplotlib
# %matplotlib inline
df.head(10)
# Out:
#    Rank               Country   iPhone  Android    MacBook Windows Powered  \
# 0     1                Kuwait  $641.50  $539.18    $795.38         $528.34
# 1     2          Saudi Arabia  $513.86  $699.61  $1,054.98         $686.88
# 2     3              Malaysia  $532.06  $631.66  $1,010.31       $1,022.67
# 3     4                Canada  $555.25  $625.04  $1,118.10       $1,081.40
# 4     5  United Arab Emirates  $498.25  $592.31  $1,073.30       $1,026.68
# 5     6                 Qatar  $608.71  $736.68    $964.36         $991.45
# 6     7                 Japan  $413.58  $548.37  $1,268.35       $1,156.57
# 7     8                   USA  $625.88  $703.94  $1,241.63         $925.69
# 8     9             Australia  $574.50  $616.66  $1,621.74         $810.34
# 9    10                Poland  $615.00  $685.74  $1,372.21       $1,151.64
#
#        PS4 Xbox one iPad mini Samsung tablet 40 inch smart TV Apple Watch  \
# ...

# %%
df=df.replace('\$','',regex=True)
df.tail()
# Out:
#     Rank    Country     iPhone    Android     MacBook Windows Powered  \
# 67    68  Guatemala     889.56     591.31    1,525.26        2,055.53
# 68    69     Brazil     843.30     948.74    3,390.96          564.91
# 69    70     Brunei     764.02     856.47    2,326.47        1,545.52
# 70    71     Angola     401.94   2,641.01    1,001.06        1,574.17
# 71    72  Venezuela  97,813.82  78,054.19  176,005.34       35,941.09
#
#           PS4   Xbox one  iPad mini Samsung tablet 40 inch smart TV  \
# 67     535.11     341.96     699.26         424.11           457.76
# 68     565.20     425.09     525.04         297.18           810.67
# 69     562.67     737.90     387.77         660.51           388.83
# 70     868.75     528.11     551.84       1,054.42         1,405.90
# 71  56,723.53  37,073.79  31,228.64      45,904.12       119,321.58
#
#    Apple Watch Brand headphone hard drive 2TB Portable charger   Printer
# ...

# %%
df=df.replace('\,','',regex=True)

# %%
filtered_countries = df[df['Country'].isin(['Spain', 'Pakistan', 'Colombia', 'Germany'])] 
filtered_countries = filtered_countries.set_index('Country')
df1 = filtered_countries[['Country','Xbox one','Portable charger']]
#df1
filtered_countries
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-7df9771b7ef7> in <module>
#       1 filtered_countries = df[df['Country'].isin(['Spain', 'Pakistan', 'Colombia', 'Germany'])]
#       2 filtered_countries = filtered_countries.set_index('Country')
# ----> 3 df1 = filtered_countries[['Country','Xbox one','Portable charger']]
#       4 #df1
#       5 filtered_countries
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...

# %%
filtered_countries = filtered_countries.set_index('Country')
android_iphone = filtered_countries[['Android','iPhone']]
android_iphone.dtypes
android_iphone=df1.astype(str).astype(float)
android_iphone.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-6fcc0227d9a3> in <module>
# ...

# %%
df1.plot(grid = True)
